# %%
import pandas as pd

import numpy as np

# %%
#csv schematics

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df.shape
# Out:
# (2810, 24)

# %%
#exonerations by race

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

race = df.loc[:,"Race"]

race_value = race.value_counts()

black_total = (1397 / 2804) * 100

white_total = (1009 / 2804) * 100

hispanic_total = (334 / 2804) * 100

native_total = (19 / 2804) * 100

#5 was removed from total individuals because of unknown race and there are 2809 total individuals because 2810 rows including header

print(race_value)

print(black_total)

print(white_total)

print(hispanic_total)

print(native_total)

black_proportion = 475,900 / 1,439,808 

#black proportion is 33%

white_proportion = (436,500 / 1,439,808) 

#white proportion is 30%

hispanic_proportion = (336,500 / 1,439,808) 

#hispanic proportion is 23%

native_proportion = (22,744 / 1,439,808)

#native proportion is 1.5%
# Out:
# Black              1397
# White              1009
# Hispanic            334
# Asian                29
# Native American      19
# Other                17
# Don't Know            5
# Name: Race, dtype: int64
# 49.82168330955778
# 35.984308131241086
# 11.911554921540656
# 0.6776034236804565

# %%
#exoneration rate by crime

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

crime = df.loc[:, "Worst Crime Display"]

crime_table = crime.value_counts()

murder_rate = (1079/2809) * 100

drug_rate = (390/2809) * 100

rape_rate = (343/2809) * 100

child_rate = (294/2809) * 100

robbery_rate = (139/2809) * 100

assault_rate = (105/2809) * 100

theft_rate = (20/2809) * 100

traffic_rate = (7/2809) * 100

forgery_rate = (4/2809) * 100

false_report_rate = (1/2809) * 100

print(crime_table)

print(murder_rate)

print(drug_rate)

print(rape_rate)

print(child_rate)

print(robbery_rate)

print(assault_rate)

print(theft_rate)

print(traffic_rate)

print(forgery_rate)

print(false_report_rate)
# Out:
# Murder                           1079
# Drug Possession or Sale           390
# Sexual Assault                    343
# Child Sex Abuse                   294
# Robbery                           139
# Assault                           105
# Attempted Murder                   67
# Manslaughter                       53
# Weapon Possession or Sale          53
# Fraud                              45
# Sex Offender Registration          32
# Arson                              23
# Theft                              20
# Burglary/Unlawful Entry            20
# Kidnapping                         16
# Other Nonviolent Felony            16
# Child Abuse                        11
# Other Violent Felony               11
# Accessory to Murder                 9
# Other Nonviolent Misdemeanor        8
# Tax Evasion/Fraud                   7
# Traffic Offense                     7
# Attempt, Violent                    6
# Threats                             6
# Bribery                             6
# ...

# %%
#total DNA exonerations

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

dna = df["DNA"]

dna_only = dna.dropna()

dna_value = dna_only.value_counts()

dna_rate = ((dna_value) / 2809) * 100

print(dna_rate)
# Out:
# DNA    19.188323
# �       0.035600
# Name: DNA, dtype: float64

# %%
#murder and false evidence

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('WorstCrimeDisplay == "Murder" and FalseEvidence == "Yes"')

print(df1)
# Out:
#             Last Name First Name   Age      Race   Sex                 State  \
# 13              Adams    Kenneth  21.0     Black  Male              Illinois
# 24    Aguirre-Jarquin   Clemente  24.0  Hispanic  Male               Florida
# 48         Allen, Jr.     George  25.0     Black  Male              Missouri
# 53             Alonzo    Quintin  21.0  Hispanic  Male                 Texas
# 66               Amor    William  39.0     White  Male              Illinois
# ...               ...        ...   ...       ...   ...                   ...
# 2755     Winfrey, Sr.    Richard  49.0     White  Male                 Texas
# 2763             Witt    Drayton  18.0     White  Male               Arizona
# 2785           Wright  Cleveland  20.0     Black  Male  District of Columbia
# 2794         Yarbough    Anthony  18.0     Black  Male              New York
# 2799       Young, Jr.        Dan  30.0     Black  Male              Illinois
#
# ...

# %%
#total false evidence 

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

FE = df["FalseEvidence"]

FE_only = FE.dropna()

total = FE_only.value_counts()

print(total)

percent = (681/2809) * 100

print(percent)
# Out:
# Yes    681
# Name: FalseEvidence, dtype: int64
# 24.243503025987895

# %%
#drug crimes and false evidence

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('WorstCrimeDisplay == "Drug Possession or Sale" and FalseEvidence == "Yes"')

print(df1)

percent = 133/681 * 100

print(percent)
# Out:
#        Last Name First Name   Age      Race     Sex   State      County  \
# 12         Adams     Johnny  52.0     Black    Male   Texas      Harris
# 28     Albritton        Amy  43.0     White  Female   Texas      Harris
# 33       Alegria      Megan  20.0     White  Female   Texas      Harris
# 67         Amory       Earl  38.0     Black    Male   Texas      Harris
# 105          Ash     Steven  54.0     White    Male  Oregon  MultnYesah
# ...          ...        ...   ...       ...     ...     ...         ...
# 2691     Wilkins      Geary  40.0     Black    Male   Texas      Harris
# 2696    Williams     Arthur  34.0     Black    Male   Texas      Harris
# 2788      Wright     Summer  20.0     Black  Female   Texas      Harris
# 2793  Yac-Garcia       Jose  27.0  Hispanic    Male   Texas      Harris
# 2804     Zarzoza   Jonathan  18.0     White    Male   Texas      Harris
#
#                   Tags        WorstCrimeDisplay List Add'l Crimes Recode  ...  \
# ...

# %%
#sexual assault and false evidence

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('WorstCrimeDisplay == "Sexual Assault" and FalseEvidence == "Yes"')

print(df1)

percent = 111/681 * 100

print(percent)
# Out:
#         Last Name    First Name   Age      Race   Sex          State  \
# 1           Abdal  Warith Habib  43.0     Black  Male       New York
# 34      Alejandro       Gilbert  35.0  Hispanic  Male          Texas
# 38      Alexander       Richard  29.0     Black  Male        Indiana
# 107        Atkins        Herman  19.0     Black  Male     California
# 162     Barnhouse       William  35.0     White  Male        Indiana
# ...           ...           ...   ...       ...   ...            ...
# 2734       Willis          John  42.0     Black  Male       Illinois
# 2761         Wise         Korey  16.0     Black  Male       New York
# 2768      Woodall          Glen  28.0     White  Male  West Virginia
# 2786  Wright, Jr.        Harold  32.0     Black  Male     Washington
# 2790        Wyatt   Rickey Dale  25.0     Black  Male          Texas
#
#           County     Tags WorstCrimeDisplay  \
# 1           Erie       IO    Sexual Assault
# 34        Uvalde      NaN    Sexual Assault
# ...

# %%
#child abuse and false evidence

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('WorstCrimeDisplay == "Child Sex Abuse" and FalseEvidence == "Yes"')

print(df1)

percent = 75/681 * 100

print(percent)
# Out:
#      Last Name First Name   Age   Race     Sex          State          County  \
# 125   Baba-Ali      Amine  31.0  Other    Male       New York          Queens
# 132       Bain   Fredrick  29.0  White    Male         Oregon         Malheur
# 133       Bain      James  19.0  Black    Male        Florida            Polk
# 146    Ballard    Frances  54.0  White  Female      Tennessee          Shelby
# 155      Baran    Bernard  18.0  White    Male  Massachusetts       Berkshire
# ...        ...        ...   ...    ...     ...            ...             ...
# 2611  Washburn    Michael  20.0  White    Male  Massachusetts         Bristol
# 2713  Williams      Jimmy  20.0  Black    Male           Ohio          Summit
# 2771     Woods    Anthony  20.0  Black    Male       Missouri  St. Louis City
# 2776   Woolson     Skippy  34.0  White    Male       New York          Oswego
# 2780      Wosu        Joy  33.0  Black  Female       New York            Erie
#
# ...

# %%
#robbery and false evidence

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('WorstCrimeDisplay == "Robbery" and FalseEvidence == "Yes"')

print(df1)

percent = 13/681 * 100

print(percent)
# Out:
#        Last Name       First Name   Age      Race   Sex       State  \
# 137        Baker         Dontrell  18.0     Black  Male     Florida
# 311       Bryant            Andre  20.0     Black  Male     Florida
# 474   Clark, Jr.            Royal  24.0     Black  Male   Louisiana
# 518       Cooper            Keith  29.0     Black  Male     Indiana
# 536     Courtney          Sedrick  23.0     Black  Male   OklahYesa
# 859        Gandy           Robert  24.0     Black  Male       Texas
# 1055      Harris          Derrick  21.0     Black  Male  California
# 1209     Jackson           Dwayne  18.0     Black  Male      Nevada
# 1673    Mervilus         Emmanuel  22.0     Black  Male  New Jersey
# 1827       Ochoa            James  19.0  Hispanic  Male  California
# 2004    Prentice             Mark  27.0     White  Male    New York
# 2121   Rodriguez          Jeffrey  24.0  Hispanic  Male  California
# 2264     Showers  Kurtis DeAngelo  28.0     Black  Male    Michigan
#
# ...

# %%
#false evidence in top crimes

total_percent_false_ev = 40.4 + 19.5 + 16.3 + 11 + 1.0 + 1.9

print(total_percent_false_ev)
# Out:
# 90.10000000000001

# %%
#assault and false evidence

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('WorstCrimeDisplay == "Assault" and FalseEvidence == "Yes"')

print(df1)

percent = 7/681 * 100

print(percent)
# Out:
#       Last Name First Name   Age   Race     Sex        State       County  \
# 1045     Harper      James  45.0  White    Male    Tennessee         Knox
# 1111  Herskovic      Mayer  20.0  White    Male     New York        Kings
# 1192  Hutchison    Leonard  39.0  White    Male    Tennessee         Knox
# 1199      Irons   Jonathan  16.0  Black    Male     Missouri  St. Charles
# 2267      Shved       Olga  23.0  White  Female   Washington     Franklin
# 2385     Stubbs      Leigh  20.0  White  Female  Mississippi      Lincoln
# 2536      Vance      Tammy  31.0  White  Female  Mississippi      Lincoln
#
#            Tags WorstCrimeDisplay  \
# 1045         PH           Assault
# 1111        NaN           Assault
# 1192        NaN           Assault
# 1199        NaN           Assault
# 2267  CV;#F;#NC           Assault
# 2385  F;#IO;#NC           Assault
# 2536  F;#IO;#NC           Assault
#
#                               List Add'l Crimes Recode  ...    *   FC  MWID  \
# ...

# %%
#perjury and false evidence

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('FalseEvidence == "Yes" and Perjury == "Yes"')

print(df1)

ev_experts = (321/681) * 100

print(ev_experts)

#structural problem with forensics experts and testimony contributing to serious wrongful convictions caused by ev
# Out:
#             Last Name   First Name   Age      Race   Sex       State  \
# 13              Adams      Kenneth  21.0     Black  Male    Illinois
# 24    Aguirre-Jarquin     Clemente  24.0  Hispanic  Male     Florida
# 34          Alejandro      Gilbert  35.0  Hispanic  Male       Texas
# 48         Allen, Jr.       George  25.0     Black  Male    Missouri
# 53             Alonzo      Quintin  21.0  Hispanic  Male       Texas
# ...               ...          ...   ...       ...   ...         ...
# 2786      Wright, Jr.       Harold  32.0     Black  Male  Washington
# 2790            Wyatt  Rickey Dale  25.0     Black  Male       Texas
# 2794         Yarbough      Anthony  18.0     Black  Male    New York
# 2799       Young, Jr.          Dan  30.0     Black  Male    Illinois
# 2806           Zimmer       Walter  40.0     White  Male        Ohio
#
#         County             Tags WorstCrimeDisplay  \
# 13        Cook   CDC;#H;#IO;#JI            Murder
# ...

# %%
#perjury and false evidence and official misconduct

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('FalseEvidence == "Yes" and Perjury == "Yes" and OfficialMisconduct == "Yes"')

print(df1)

ev_experts = (239/681) * 100

print(ev_experts)
# Out:
#         Last Name   First Name   Age      Race   Sex           State  \
# 13          Adams      Kenneth  21.0     Black  Male        Illinois
# 34      Alejandro      Gilbert  35.0  Hispanic  Male           Texas
# 48     Allen, Jr.       George  25.0     Black  Male        Missouri
# 53         Alonzo      Quintin  21.0  Hispanic  Male           Texas
# 96      Armstrong      LaMonte  38.0     Black  Male  North Carolina
# ...           ...          ...   ...       ...   ...             ...
# 2786  Wright, Jr.       Harold  32.0     Black  Male      Washington
# 2790        Wyatt  Rickey Dale  25.0     Black  Male           Texas
# 2794     Yarbough      Anthony  18.0     Black  Male        New York
# 2799   Young, Jr.          Dan  30.0     Black  Male        Illinois
# 2806       Zimmer       Walter  40.0     White  Male            Ohio
#
#         County             Tags WorstCrimeDisplay  \
# 13        Cook   CDC;#H;#IO;#JI            Murder
# ...

# %%
#perjury and official misconduct

df2 = df.query('Perjury == "Yes" and OfficialMisconduct == "Yes"')

print(df2)

PE_only = df2.dropna()

total = PE_only.value_counts()

percent = (1247/1695) * 100

print(percent)
# Out:
#        Last Name   First Name   Age      Race   Sex         State  \
# 2      Abernathy  Christopher  17.0     White  Male      Illinois
# 5          Adams      Anthony  26.0  Hispanic  Male    California
# 8          Adams     Demetris  22.0     Black  Male      Illinois
# 9          Adams      Don Ray  32.0     Black  Male  Pennsylvania
# 13         Adams      Kenneth  21.0     Black  Male      Illinois
# ...          ...          ...   ...       ...   ...           ...
# 2799  Young, Jr.          Dan  30.0     Black  Male      Illinois
# 2801     Yurtman        Ersan  18.0  Hispanic  Male         Texas
# 2802       Yusuf       Yassin  19.0     Black  Male        Fed-TN
# 2806      Zimmer       Walter  40.0     White  Male          Ohio
# 2808  Zinkiewicz       Tyrone  38.0     White  Male          Ohio
#
#             County              Tags        WorstCrimeDisplay  \
# 2             Cook    CIU;#CV;#H;#IO                   Murder
# ...

# %%
#total perjury

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

PE = df["Perjury"]

PE_only = PE.dropna()

total = PE_only.value_counts()

print(total)

percent = (1247/1695) * 100

print(percent)
# Out:
# Yes    1695
# Name: Perjury, dtype: int64
# 73.5693215339233

# %%
#percent total perjury

perjury_total = 1695 / 2809 * 100

print (perjury_total)
# Out:
# 60.34175863296547

# %%
#total mistaken witness


df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

MW = df["MistakenWitness"]

MW_only = MW.dropna()

total = MW_only.value_counts()

print(total)
# Out:
# Yes    792
# Name: MistakenWitness, dtype: int64

# %%
#mistaken witness and perjury

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')
df1 = df.query('MistakenWitness == "Yes" and Perjury == "Yes"')

print(df1)

percent = (267/792) * 100

print(percent)
# Out:
#       Last Name    First Name   Age             Race   Sex          State  \
# 13        Adams       Kenneth  21.0            Black  Male       Illinois
# 15        Adams  Randall Dale  28.0            White  Male          Texas
# 34    Alejandro       Gilbert  35.0         Hispanic  Male          Texas
# 37    Alexander       Malcolm  19.0            Black  Male      Louisiana
# 39       Alford       Herbert  38.0            Black  Male       Michigan
# ...         ...           ...   ...              ...   ...            ...
# 2768    Woodall          Glen  28.0            White  Male  West Virginia
# 2789  Wurdemann          John  29.0  Native American  Male          Idaho
# 2790      Wyatt   Rickey Dale  25.0            Black  Male          Texas
# 2791   Wyniemko       Kenneth  42.0            White  Male       Michigan
# 2795     Yarris      Nicholas  20.0            White  Male   Pennsylvania
#
#          County            Tags WorstCrimeDisplay  \
# ...

# %%
#mistaken witness and false evidence

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('MistakenWitness == "Yes" and FalseEvidence == "Yes"')

print(df1)

percent = (180/792) * 100

print(percent)
# Out:
#       Last Name    First Name   Age      Race   Sex          State  \
# 1         Abdal  Warith Habib  43.0     Black  Male       New York
# 13        Adams       Kenneth  21.0     Black  Male       Illinois
# 34    Alejandro       Gilbert  35.0  Hispanic  Male          Texas
# 38    Alexander       Richard  29.0     Black  Male        Indiana
# 53       Alonzo       Quintin  21.0  Hispanic  Male          Texas
# ...         ...           ...   ...       ...   ...            ...
# 2727   Williams        Willie  23.0     Black  Male        Georgia
# 2734     Willis          John  42.0     Black  Male       Illinois
# 2768    Woodall          Glen  28.0     White  Male  West Virginia
# 2771      Woods       Anthony  20.0     Black  Male       Missouri
# 2790      Wyatt   Rickey Dale  25.0     Black  Male          Texas
#
#               County            Tags WorstCrimeDisplay  \
# 1               Erie              IO    Sexual Assault
# ...

# %%
#total insufficient legal defense

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

ILD = df["ILD"]
ILD_only = ILD.dropna()

total = ILD_only.value_counts()

print(total)


percent = (767/2809) * 100

print(percent)
# Out:
# ILD    767
# Name: ILD, dtype: int64
# 27.30509077963688

# %%
#insufficient legal defense after 1989

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('ILD == "ILD" and Convicted > 1989')

#1989 was chosen as it entailed a massive upsurge in population - man mins created in 1986

print(df1)

percent = (624/767) * 100

print(percent)
# Out:
#             Last Name  First Name   Age             Race     Sex       State  \
# 4               Acero     Longino  35.0         Hispanic    Male  California
# 10              Adams  Jarrett M.  17.0            Black    Male   Wisconsin
# 21            Addison      Ronald  19.0            Black    Male    Maryland
# 24    Aguirre-Jarquin    Clemente  24.0         Hispanic    Male     Florida
# 25              Ahmed     Mubarez  31.0            Other    Male    Michigan
# ...               ...         ...   ...              ...     ...         ...
# 2780             Wosu         Joy  33.0            Black  Female    New York
# 2789        Wurdemann        John  29.0  Native American    Male       Idaho
# 2794         Yarbough     Anthony  18.0            Black    Male    New York
# 2803           Zapata     Rodrigo  25.0         Hispanic    Male       Texas
# 2807        Zimmerman        Evan  53.0            White    Male   Wisconsin
#
# ...

# %%
#drug crimes and insufficient legal defense

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('ILD == "ILD" and WorstCrimeDisplay == "Drug Possession or Sale"')

print(df1)

percent = 22 / 767 * 100

print(percent)
# Out:
#        Last Name   First Name   Age             Race     Sex          State  \
# 149      Baltrip        Henry  22.0            Black    Male          Texas
# 191    Bell, Jr.        James  27.0            Black    Male   Pennsylvania
# 256        Bragg    Rodney L.  31.0            Black    Male       Arkansas
# 434   Chancellor       Darell  29.0            Black    Male       Michigan
# 526       Cortez       Arturo  34.0         Hispanic    Male     California
# 673        Dixon  Christopher  31.0            Black    Male          Texas
# 799         Fils       Roland  35.0            Black    Male  Massachusetts
# 955    Granberry      Roxanne  33.0            White  Female         Fed-VA
# 981        Gregg         Cody  26.0  Native American    Male      OklahYesa
# 1004      Guzman     Humberto  40.0         Hispanic    Male  Massachusetts
# 1104   Hernandez        Maria  39.0         Hispanic  Female         Fed-TX
# ...

# %%
#murder and insufficient legal defense

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('ILD == "ILD" and WorstCrimeDisplay == "Murder"')

print(df1)


percent = 355 / 767 * 100

print(percent)
# Out:
#             Last Name First Name   Age      Race   Sex          State  \
# 14              Adams   Laurence  19.0     Black  Male  Massachusetts
# 21            Addison     Ronald  19.0     Black  Male       Maryland
# 24    Aguirre-Jarquin   Clemente  24.0  Hispanic  Male        Florida
# 25              Ahmed    Mubarez  31.0     Other  Male       Michigan
# 29              Alcox       Joel  22.0     White  Male     California
# ...               ...        ...   ...       ...   ...            ...
# 2764          Woidtke     Rodney  27.0     White  Male       Illinois
# 2766             Wong      David  23.0     Asian  Male       New York
# 2794         Yarbough    Anthony  18.0     Black  Male       New York
# 2795           Yarris   Nicholas  20.0     White  Male   Pennsylvania
# 2807        Zimmerman       Evan  53.0     White  Male      Wisconsin
#
#               County             Tags WorstCrimeDisplay  \
# 14           Suffolk            H;#JI            Murder
# ...

# %%
#sexual assault and insufficient legal defense

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('ILD == "ILD" and WorstCrimeDisplay == "Sexual Assault"')

print(df1)

percent = 61 / 767 * 100

print(percent)
# Out:
#       Last Name   First Name   Age      Race   Sex           State  \
# 10        Adams   Jarrett M.  17.0     Black  Male       Wisconsin
# 37    Alexander      Malcolm  19.0     Black  Male       Louisiana
# 54     Alowonle       Rilwan  50.0     Black  Male       Minnesota
# 119      Aviles      Anselmo  22.0  Hispanic  Male   Massachusetts
# 177      Baylor       Ronnie  25.0     Black  Male      California
# ...         ...          ...   ...       ...   ...             ...
# 2587     Walker       Joseph  44.0     Black  Male  South Carolina
# 2598      Walls       George  39.0     Black  Male    Pennsylvania
# 2679    Wickham  Christopher  27.0     White  Male            Utah
# 2690  Wilkerson         Mike  39.0     White  Male        Missouri
# 2790      Wyatt  Rickey Dale  25.0     Black  Male           Texas
#
#           County     Tags WorstCrimeDisplay  \
# 10     Jefferson   IO;#NC    Sexual Assault
# 37     Jefferson       IO    Sexual Assault
# ...

# %%
#false confessions and insufficient legal defense

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('FC == "FC" and ILD == "ILD"')

print(df1)

percent = 106 / 344 * 100

print(percent)
# Out:
#       Last Name First Name   Age   Race   Sex         State         County  \
# 22        Agnew    Gregory  28.0  Black  Male      Illinois           Lake
# 29        Alcox       Joel  22.0  White  Male    California  Santa Barbara
# 138       Baker     Edward  17.0  Black  Male  Pennsylvania   Philadelphia
# 177      Baylor     Ronnie  25.0  Black  Male    California      Riverside
# 189        Bell     George  19.0  Black  Male      New York         Queens
# ...         ...        ...   ...    ...   ...           ...            ...
# 2751     Wilson    Sharrif  15.0  Black  Male      New York          Kings
# 2764    Woidtke     Rodney  27.0  White  Male      Illinois      St. Clair
# 2794   Yarbough    Anthony  18.0  Black  Male      New York          Kings
# 2795     Yarris   Nicholas  20.0  White  Male  Pennsylvania       Delaware
# 2807  Zimmerman       Evan  53.0  White  Male     Wisconsin     Eau Claire
#
#                  Tags WorstCrimeDisplay  \
# ...

# %%
#total number of false confessions

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

FC = df["FC"]
FC_only = FC.dropna()

total = FC_only.value_counts()

print(total)
# Out:
# FC    344
# Name: FC, dtype: int64

# %%
#total number of official misconduct

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

FC = df["OfficialMisconduct"]
FC_only = FC.dropna()

total = FC_only.value_counts()

print(total)
# Out:
# Yes    1552
# Name: OfficialMisconduct, dtype: int64

# %%
#age stats

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df.describe()
# Out:
#                Age    Convicted   Exonerated
# count  2800.000000  2810.000000  2810.000000
# mean     28.557500  1997.899288  2009.220285
# std      10.224398    10.988950     8.611232
# min      11.000000  1956.000000  1989.000000
# 25%      20.000000  1990.000000  2002.000000
# 50%      26.000000  1997.000000  2012.000000
# 75%      35.000000  2007.000000  2016.000000
# max      83.000000  2020.000000  2021.000000

# %%
#total count per state

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

pd.set_option('display.max_rows', 500)

FC = df["State"]

total = FC.value_counts()

print(total)


texas = 392/2809 * 100

il = 351/2809 * 100

ny = 290/2809 * 100

ca = 233/2809 * 100

mi = 134/2809 * 100
# Out:
# Texas                   392
# Illinois                351
# New York                290
# California              233
# Michigan                134
# Pennsylvania             98
# Ohio                     85
# Massachusetts            77
# Florida                  76
# North Carolina           66
# Louisiana                63
# Wisconsin                59
# Virginia                 56
# Washington               50
# Missouri                 50
# Georgia                  44
# New Jersey               42
# Maryland                 40
# Indiana                  38
# OklahYesa                38
# Connecticut              29
# Alabama                  27
# Tennessee                24
# Mississippi              23
# Arizona                  22
# Oregon                   22
# Kentucky                 22
# Fed-NY                   21
# Nevada                   20
# District of Columbia     19
# Utah                     18
# Minnesota                17
# Iowa                     16
# ...

# %%
#total count per collumn

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df.count()
# Out:
# Last Name                   2810
# First Name                  2810
# Age                         2800
# Race                        2810
# Sex                         2810
# State                       2810
# County                      2759
# Tags                        2532
# WorstCrimeDisplay           2810
# List Add'l Crimes Recode    1141
# Sentence                    2810
# Convicted                   2810
# Exonerated                  2810
# DNA                          540
# *                            163
# FC                           344
# MistakenWitness              792
# FalseEvidence                681
# Perjury                     1695
# OfficialMisconduct          1552
# ILD                          767
# Posting Date                2810
# Yes Tags                    1552
# Date of Crime Year          2810
# dtype: int64

# %%
#within texas analysis

per_capita_exoneration = (392 * 100000) / 29000000


df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('State == "Texas"')

percent = 70/392 * 100

#197 Texas CIU and 392 total CIU

percent2 = 197/392 *100

#46 Texas + IO and 392 total IO

percent3 = 46/392 *100

print(df1)

print(percent)

print(percent2)

print(percent3)

print(per_capita_exoneration)
# Out:
#           Last Name    First Name   Age      Race     Sex  State  County  \
# 7             Adams       Darryl   25.0     Black    Male  Texas  Dallas
# 12            Adams        Johnny  52.0     Black    Male  Texas  Harris
# 15            Adams  Randall Dale  28.0     White    Male  Texas  Dallas
# 28        Albritton           Amy  43.0     White  Female  Texas  Harris
# 30    Aldape Guerra      Ricardo   20.0  Hispanic    Male  Texas  Harris
# ...             ...           ...   ...       ...     ...    ...     ...
# 2790          Wyatt   Rickey Dale  25.0     Black    Male  Texas  Dallas
# 2793     Yac-Garcia          Jose  27.0  Hispanic    Male  Texas  Harris
# 2801        Yurtman         Ersan  18.0  Hispanic    Male  Texas   Bexar
# 2803         Zapata       Rodrigo  25.0  Hispanic    Male  Texas    Webb
# 2804        Zarzoza      Jonathan  18.0     White    Male  Texas  Harris
#
#                   Tags      Worst Crime Display  \
# ...

# %%
#illinois analysis

per_capita_exoneration = (351 * 100000) / 12670000


df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('State == "Illinois" and DNA == "DNA"')

percent = 63/540 * 100

#127 Ill + CIU and 500 total CIU

percent2 = 127/500 *100

#171 Ill + IO and 447 total IO

percent3 = 171/447 *100

print(df1)

print(percent)

print(percent2)

print(percent3)

print(per_capita_exoneration)
# Out:
#          Last Name   First Name   Age      Race     Sex     State     County  \
# 2        Abernathy  Christopher  17.0     White    Male  Illinois       Cook
# 13           Adams      Kenneth  21.0     Black    Male  Illinois       Cook
# 69        Andersen       Daniel  19.0     White    Male  Illinois       Cook
# 129         Bailey        Kevin  19.0     Black    Male  Illinois       Cook
# 163           Barr     Jonathan  14.0     Black    Male  Illinois       Cook
# 170      Batchelor        Corey  19.0     Black    Male  Illinois       Cook
# 249       Bradford   Marcellius  17.0     Black    Male  Illinois       Cook
# 283    Brooks, Jr.       Claude  35.0     Black    Male  Illinois       Cook
# 320        Bullock       Ronnie  27.0     Black    Male  Illinois       Cook
# 358           Cage        Dean   28.0     Black    Male  Illinois       Cook
# 388         Carini      William  28.0     White    Male  Illinois       Lake
# ...

# %%
#within illinois analysis

per_capita_exoneration = (351 * 100000) / 12670000


df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('State == "Illinois" and DNA == "DNA"')

percent = 63/351 * 100

#127 Ill + CIU and 500 total CIU

percent2 = 127/351 *100

#171 Ill + IO and 447 total IO

percent3 = 171/351 *100

print(df1)

print(percent)

print(percent2)

print(percent3)

print(per_capita_exoneration)
# Out:
#          Last Name   First Name   Age      Race     Sex     State     County  \
# 2        Abernathy  Christopher  17.0     White    Male  Illinois       Cook
# 13           Adams      Kenneth  21.0     Black    Male  Illinois       Cook
# 69        Andersen       Daniel  19.0     White    Male  Illinois       Cook
# 129         Bailey        Kevin  19.0     Black    Male  Illinois       Cook
# 163           Barr     Jonathan  14.0     Black    Male  Illinois       Cook
# 170      Batchelor        Corey  19.0     Black    Male  Illinois       Cook
# 249       Bradford   Marcellius  17.0     Black    Male  Illinois       Cook
# 283    Brooks, Jr.       Claude  35.0     Black    Male  Illinois       Cook
# 320        Bullock       Ronnie  27.0     Black    Male  Illinois       Cook
# 358           Cage        Dean   28.0     Black    Male  Illinois       Cook
# 388         Carini      William  28.0     White    Male  Illinois       Lake
# ...

# %%
#new york analysis

per_capita_exoneration = (290 * 100000) / 8419000

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('State == "New York" and DNA == "DNA"')

percent = 50/540 * 100

#58 New York + CIU and 500 total CIU

percent2 = 57/499 *100

#52 New York + IO and 447 total IO

percent3 = 51/446 *100

print(df1)

print(percent)

print(percent2)

print(percent3)

print(per_capita_exoneration)
# Out:
#        Last Name    First Name   Age             Race     Sex     State  \
# 1          Abdal  Warith Habib  43.0            Black    Male  New York
# 126         Babb        Austin  20.0            Black    Male  New York
# 161       Barnes        Steven  19.0            White    Male  New York
# 303        Brown           Roy  29.0            White    Male  New York
# 347         Bush         Keith  17.0            Black    Male  New York
# 362      Callace       Leonard  30.0            White    Male  New York
# 381      Capozzi       Anthony  27.0            White    Male  New York
# 430     Chalmers         Terry  20.0            Black    Male  New York
# 511       Connor      Reginald  23.0            Black    Male  New York
# 534       Counts       Gregory  19.0            Black    Male  New York
# 588        Dabbs       Charles  27.0            Black    Male  New York
# 628         Days        Selwyn  32.0            Black    Male  New York
# ...

# %%
#within new york analysis

per_capita_exoneration = (290 * 100000) / 8419000

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('State == "New York" and DNA == "DNA"')

percent = 50/290 * 100

#58 New York + CIU and 500 total CIU

percent2 = 57/290 *100

#52 New York + IO and 447 total IO

percent3 = 51/290 *100

print(df1)

print(percent)

print(percent2)

print(percent3)
# Out:
#        Last Name    First Name   Age             Race     Sex     State  \
# 1          Abdal  Warith Habib  43.0            Black    Male  New York
# 126         Babb        Austin  20.0            Black    Male  New York
# 161       Barnes        Steven  19.0            White    Male  New York
# 303        Brown           Roy  29.0            White    Male  New York
# 347         Bush         Keith  17.0            Black    Male  New York
# 362      Callace       Leonard  30.0            White    Male  New York
# 381      Capozzi       Anthony  27.0            White    Male  New York
# 430     Chalmers         Terry  20.0            Black    Male  New York
# 511       Connor      Reginald  23.0            Black    Male  New York
# 534       Counts       Gregory  19.0            Black    Male  New York
# 588        Dabbs       Charles  27.0            Black    Male  New York
# 628         Days        Selwyn  32.0            Black    Male  New York
# ...

# %%
#louisiana analysis

per_capita_exoneration = (63 * 100000) / 4649000

df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('State == "Louisiana" and DNA == "DNA"')

percent = 19/63 * 100

#4 CIU and 63 total LA

percent2 = 4/63 *100

#31 IO and 63 total LA

percent3 = 31/63 *100

print(df1)

print(percent)

print(percent2)

print(percent3)

print(per_capita_exoneration)



print(per_capita_exoneration)
# Out:
#        Last Name       First Name   Age   Race   Sex      State       County  \
# 37     Alexander          Malcolm  19.0  Black  Male  Louisiana    Jefferson
# 207      Bibbins             Gene  29.0  Black  Male  Louisiana    LA Parish
# 292        Brown           Dennis  16.0  Black  Male  Louisiana  St. Tammany
# 300        Brown           Nathan  23.0  Black  Male  Louisiana    Jefferson
# 442      Charles            Clyde  26.0  Black  Male  Louisiana   Terrebonne
# 486         Coco            Allen  26.0  Black  Male  Louisiana    Calcasieu
# 814        Floyd             John  31.0  White  Male  Louisiana      Orleans
# 1082       Hayes           Travis  17.0  Black  Male  Louisiana    Jefferson
# 1121        Hill           Darrin  26.0  Black  Male  Louisiana      Orleans
# 1220     Jackson           Willie  17.0  Black  Male  Louisiana    Jefferson
# 1229       James            Henry  20.0  Black  Male  Louisiana    Jefferson
# ...

# %%
#fed analysis

fed_total = 21 + 13 + 12 + 6 + 17 + 5 + 15 + 8 + 6 + 7 + 2 + 9 

fed_percent = (fed_total / 2809) * 100

print(fed_total)

print(fed_percent)

#DNA for fed

dna_fed = 1/121 * 100

#NO USE OF CIU OR IO

PR_dna = 63/121 * 100

OM_dna = 77/121 * 100

per_dna = 73/121 * 100

false_ev_fed = 11/121 * 100

print(dna_fed)

print(PR_dna)

print(OM_dna)

print(per_dna)

print(false_ev_fed)
# Out:
# 121
# 4.307582769668921
# 0.8264462809917356
# 52.066115702479344
# 63.63636363636363
# 60.33057851239669
# 9.090909090909092

# %%
#new hampshire analysis

per_capita = (2 * 100000) / 1360000

print(per_capita)
# Out:
# 0.14705882352941177

# %%
#maryland analysis

per_capita = (40 * 100000) / 6046000

print(per_capita)
# Out:
# 0.6615944426066821

# %%
#wyoming analysis

# %%
#south carolina analysis

per_capita = (9 * 100000) / 5149000

print(per_capita)
# Out:
# 0.1747912215964265

# %%
total_ciu = 500/1820 * 100

ciu_last_five_years = 272/689 * 100

print(total_ciu)

print(ciu_last_five_years)
# Out:
# 27.472527472527474
# 39.477503628447025

# %%
df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('State == "Illinois" and Exonerated > 2002 and DNA == "DNA"')

exonerated_percent = 293/351 * 100

print(df1)


print(exonerated_percent)
# Out:
#         Last Name   First Name   Age      Race   Sex     State     County  \
# 2       Abernathy  Christopher  17.0     White  Male  Illinois       Cook
# 69       Andersen       Daniel  19.0     White  Male  Illinois       Cook
# 129        Bailey        Kevin  19.0     Black  Male  Illinois       Cook
# 163          Barr     Jonathan  14.0     Black  Male  Illinois       Cook
# 170     Batchelor        Corey  19.0     Black  Male  Illinois       Cook
# 283   Brooks, Jr.       Claude  35.0     Black  Male  Illinois       Cook
# 358          Cage        Dean   28.0     Black  Male  Illinois       Cook
# 388        Carini      William  28.0     White  Male  Illinois       Lake
# 496       Coleman       Nevest  25.0     Black  Male  Illinois       Cook
# 605         Davis        Andre  19.0     Black  Male  Illinois  Champaign
# 732       Edwards        James  44.0     Black  Male  Illinois       Lake
# 766         Evans      Michael  17.0     Black  Male  Illinois       Cook
# ...

# %%
df = pd.read_csv('/Users/kanshruti/Downloads/Exoneration Data.csv')

df1 = df.query('State == "Louisiana" and Exonerated > 2000')

exonerated_percent = 293/351 * 100

print(df1)


print(exonerated_percent)
# Out:
#           Last Name       First Name   Age      Race     Sex      State  \
# 16            Adams         Reginald  26.0     Black    Male  Louisiana
# 37        Alexander          Malcolm  19.0     Black    Male  Louisiana
# 199         Beridon           Cheryl  23.0     Black  Female  Louisiana
# 207         Bibbins             Gene  29.0     Black    Male  Louisiana
# 267          Bright           Dan L.  35.0     Black    Male  Louisiana
# 268          Bright          Gregory  20.0     Black    Male  Louisiana
# 269          Briley           Yutico  19.0     Black    Male  Louisiana
# 292           Brown           Dennis  16.0     Black    Male  Louisiana
# 300           Brown           Nathan  23.0     Black    Male  Louisiana
# 337         Burrell           Albert  30.0     White    Male  Louisiana
# 474      Clark, Jr.            Royal  24.0     Black    Male  Louisiana
# 486            Coco            Allen  26.0     Black    Male  Louisiana
# ...
